# %% [markdown]
# **Analisis exploratorio** del dataframe. lo primero que deberéis hacer es un pequeño análisis exploratorio donde saquéis:
#
# - Número de filas y columnas
#
# - Cuáles son los nombres de las columnas
#
# - Los nombres de las columnas tienen espacios. Cambiar los nombres de las columnas, para que en vez de espacios tengan "_"
#
# - ¿Cuántos nulos tiene nuestro df? Mostrad solo aquellas filas que tengan nulos y en formato del porcentaje
#
# - ¿Tenemos duplicados en nuestro df?
#
# - ¿Cuáles son los principales estadísticos de las variables numéricas? ¿Y de las categóricas? Mostrad los resultados por separado.
#
# - Cread un subdataframe que contenga unicamente las columnas de tipo *object*

# %%
import pandas as pd
import numpy as np

# %%
df_movies = pd.read_csv("movies_metadata.csv")
# Out:
# C:\Users\Sindri\AppData\Local\Temp\ipykernel_23588\1104718544.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_movies = pd.read_csv("movies_metadata.csv")

# %%
df_movies
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview  ... release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4      Just when George Banks has recovered from his ...  ...   1995-02-10
# ...                                                  ...  ...          ...
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45461          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45463          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45464          0.0    87.0                                                 []
# 45465          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45461  Released         Rising and falling between a man and woman
# 45462  Released                                                NaN
# 45463  Released                             A deadly game of wits.
# 45464  Released                                                NaN
# 45465  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45461                       Subdue  False          4.0        1.0
# 45462          Century of Birthing  False          9.0        3.0
# 45463                     Betrayal  False          3.8        6.0
# 45464             Satan Triumphant  False          0.0        0.0
# 45465                     Queerama  False          0.0        0.0
#
# [45466 rows x 24 columns]

# %%
df_movies.shape
# Out:
# (45466, 24)

# %%
df_movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
nuevas_columnas = [old_colums.replace(" ","_") for old_colums in df_movies.columns]

# %%
df_movies.columns = nuevas_columnas

# %%
df_movies
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview  ... release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4      Just when George Banks has recovered from his ...  ...   1995-02-10
# ...                                                  ...  ...          ...
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45461          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45463          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45464          0.0    87.0                                                 []
# 45465          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45461  Released         Rising and falling between a man and woman
# 45462  Released                                                NaN
# 45463  Released                             A deadly game of wits.
# 45464  Released                                                NaN
# 45465  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45461                       Subdue  False          4.0        1.0
# 45462          Century of Birthing  False          9.0        3.0
# 45463                     Betrayal  False          3.8        6.0
# 45464             Satan Triumphant  False          0.0        0.0
# 45465                     Queerama  False          0.0        0.0
#
# [45466 rows x 24 columns]

# %%
df_movies_nulos = pd.DataFrame(df_movies.isnull().sum() / df_movies.shape[0]*100)
df_movies_nulos2 = df_movies_nulos[df_movies_nulos[0] > 0]
df_movies_nulos2
# Out:
#                                0
# belongs_to_collection  90.115691
# homepage               82.883913
# imdb_id                 0.037391
# original_language       0.024194
# overview                2.098271
# popularity              0.010997
# poster_path             0.848986
# production_companies    0.006598
# production_countries    0.006598
# release_date            0.191352
# revenue                 0.013197
# runtime                 0.578454
# spoken_languages        0.013197
# status                  0.191352
# tagline                55.104914
# title                   0.013197
# video                   0.013197
# vote_average            0.013197
# vote_count              0.013197

# %%
df_movies.duplicated().sum()
# Out:
# 13

# %%
df_movies.describe().T
# Out:
#                 count          mean           std  min   25%   50%    75%  \
# revenue       45460.0  1.120935e+07  6.433225e+07  0.0   0.0   0.0    0.0
# runtime       45203.0  9.412820e+01  3.840781e+01  0.0  85.0  95.0  107.0
# vote_average  45460.0  5.618207e+00  1.924216e+00  0.0   5.0   6.0    6.8
# vote_count    45460.0  1.098973e+02  4.913104e+02  0.0   3.0  10.0   34.0
#
#                        max
# revenue       2.787965e+09
# runtime       1.256000e+03
# vote_average  1.000000e+01
# vote_count    1.407500e+04

# %%
df_movies.describe(include = "object")
# Out:
#         adult                              belongs_to_collection budget  \
# count   45466                                               4494  45466
# unique      5                                               1698   1226
# top     False  {'id': 415931, 'name': 'The Bowery Boys', 'pos...      0
# freq    45454                                                 29  36573
#
#                                genres                     homepage      id  \
# count                           45466                         7782   45466
# unique                           4069                         7673   45436
# top     [{'id': 18, 'name': 'Drama'}]  http://www.georgecarlin.com  141971
# freq                             5000                           12       3
#
#           imdb_id original_language original_title            overview  \
# count       45449             45455          45466               44512
# unique      45417                92          43373               44307
# top     tt1180333                en         Hamlet  No overview found.
# freq            3             32269              8                 133
#
#        popularity                       poster_path production_companies  \
# count       45461                             45080                45463
# unique      44176                             45024                22708
# top           0.0  /5D7UBSEgdyONE6Lql6xS7s6OLcW.jpg                   []
# freq           34                                 5                11875
#
#                                      production_countries release_date  \
# count                                               45463        45379
# unique                                               2393        17336
# top     [{'iso_3166_1': 'US', 'name': 'United States o...   2008-01-01
# freq                                                17851          136
#
#                                 spoken_languages    status  \
# count                                      45460     45379
# unique                                      1931         6
# top     [{'iso_639_1': 'en', 'name': 'English'}]  Released
# freq                                       22395     45014
#
#                        tagline       title  video
# count                    20412       45460  45460
# unique                   20283       42277      2
# top     Based on a true story.  Cinderella  False
# freq                         7          11  45367

# %%
df_movies_categoricos = df_movies.describe(include = "object").T
df_movies_categoricos
# Out:
#                        count unique  \
# adult                  45466      5
# belongs_to_collection   4494   1698
# budget                 45466   1226
# genres                 45466   4069
# homepage                7782   7673
# id                     45466  45436
# imdb_id                45449  45417
# original_language      45455     92
# original_title         45466  43373
# overview               44512  44307
# popularity             45461  44176
# poster_path            45080  45024
# production_companies   45463  22708
# production_countries   45463   2393
# release_date           45379  17336
# spoken_languages       45460   1931
# status                 45379      6
# tagline                20412  20283
# title                  45460  42277
# video                  45460      2
#
#                                                                      top  \
# adult                                                              False
# belongs_to_collection  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# budget                                                                 0
# genres                                     [{'id': 18, 'name': 'Drama'}]
# homepage                                     http://www.georgecarlin.com
# id                                                                141971
# imdb_id                                                        tt1180333
# original_language                                                     en
# original_title                                                    Hamlet
# overview                                              No overview found.
# popularity                                                           0.0
# poster_path                             /5D7UBSEgdyONE6Lql6xS7s6OLcW.jpg
# production_companies                                                  []
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  2008-01-01
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                                           Based on a true story.
# title                                                         Cinderella
# video                                                              False
#
#                         freq
# adult                  45454
# belongs_to_collection     29
# budget                 36573
# genres                  5000
# homepage                  12
# id                         3
# imdb_id                    3
# original_language      32269
# original_title             8
# overview                 133
# popularity                34
# poster_path                5
# production_companies   11875
# production_countries   17851
# release_date             136
# spoken_languages       22395
# status                 45014
# tagline                    7
# title                     11
# video                  45367

# %%
df_movies_categoricos = df_movies.describe(include = "object").T
df_movies_categoricos
# Out:
#                        count unique  \
# adult                  45466      5
# belongs_to_collection   4494   1698
# budget                 45466   1226
# genres                 45466   4069
# homepage                7782   7673
# id                     45466  45436
# imdb_id                45449  45417
# original_language      45455     92
# original_title         45466  43373
# overview               44512  44307
# popularity             45461  44176
# poster_path            45080  45024
# production_companies   45463  22708
# production_countries   45463   2393
# release_date           45379  17336
# spoken_languages       45460   1931
# status                 45379      6
# tagline                20412  20283
# title                  45460  42277
# video                  45460      2
#
#                                                                      top  \
# adult                                                              False
# belongs_to_collection  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# budget                                                                 0
# genres                                     [{'id': 18, 'name': 'Drama'}]
# homepage                                     http://www.georgecarlin.com
# id                                                                141971
# imdb_id                                                        tt1180333
# original_language                                                     en
# original_title                                                    Hamlet
# overview                                              No overview found.
# popularity                                                           0.0
# poster_path                             /5D7UBSEgdyONE6Lql6xS7s6OLcW.jpg
# production_companies                                                  []
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  2008-01-01
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                                           Based on a true story.
# title                                                         Cinderella
# video                                                              False
#
#                         freq
# adult                  45454
# belongs_to_collection     29
# budget                 36573
# genres                  5000
# homepage                  12
# id                         3
# imdb_id                    3
# original_language      32269
# original_title             8
# overview                 133
# popularity                34
# poster_path                5
# production_companies   11875
# production_countries   17851
# release_date             136
# spoken_languages       22395
# status                 45014
# tagline                    7
# title                     11
# video                  45367

# %% [markdown]
# **Cread una columna que se llame `id`, que contenga números consecutivos que no se repitan**

# %%
df_movies.reset_index

df_movies.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %% [markdown]
# **Cread una columma nueva usando la columna `stays_in_weekend_nights`**
#
# Basandonos en esta columna queremos dividir las estancias en dos categorías:
#
# - Estancias superiores a 5 dias serán etiquetadas como "long stay"
#
# - Estancias iguales o inferiores a 5 días serán consideradas como "short stay"
#
# - Cread una nueva columna que se llame "stays_type"
#
# - Mostrad las 6 últimas filas

# %%
df_movies["vote_type"] =  np.where(df_movies["vote_average"] > 7, "Good Rating", "Bad Rating")
df_movies.head()
#Aqui filtro las peliculas en base a sus notas.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 df_movies["vote_type"] =  np.where(df_movies["vote_average"] > 7, "Good Rating", "Bad Rating")
#       2 df_movies.head()
#
# NameError: name 'np' is not defined

# %%
df_movies["vote_type"].describe(include = "object").T
# Out:
# count           45466
# unique              2
# top       Good Rating
# freq            33571
# Name: vote_type, dtype: object

# %% [markdown]
# **Basandonos en la columna `required_car_parking_spaces`:**
#
# - Chequead los valores únicos de la columna
#
# - De cada una de las categorías de la columna, ¿cuántos registros tenemos de cada uno de ellos? Mostrad este resultado como un DataFrame
#
# - Esta columna está en formato numérico y no nos interesa. Cambiad los 0 por "No" y mayores que 0 por "Si"
#
# - Cread una nueva columna que se llame "parking"

# %%
#Las funciones para mis map
def scanner(s):
    try:
        i = int(s)
        return i
    except:
        return 0
def mode_budget(budget):
    if budget == 0:
        budget = df_Movies_Budget_Mode
        return budget
    else:
        return budget

# %%
df_Movies_Budget = df_movies["budget"].value_counts().reset_index()
#Cambio el nombre de las columnas.
df_Movies_Budget.rename(columns={"index":"Budget","budget":"Same_Budget"},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 df_Movies_Budget = df_movies["budget"].value_counts().reset_index()
#       2 #Cambio el nombre de las columnas.
#       3 df_Movies_Budget.rename(columns={"index":"Budget","budget":"Same_Budget"},inplace=True)
#
# NameError: name 'df_movies' is not defined

# %%
#Aqui realizo mi primer map, convierto todos los str en int y los str que no se pueden transformar se pasan a 0.
df_Movies_Budget["Budget"] = list(map(scanner, df_Movies_Budget["Budget"]))
#Hago la moda del Budget.
df_Movies_Budget_Mode = df_Movies_Budget["Budget"].mode()

# %%
#Y aqui corro el segundo map para aplicar la moda a todos los 0.
df_Movies_Budget["Budget"] = list(map(mode_budget,df_Movies_Budget["Budget"]))
df_Movies_Budget["Large_Budget"] = np.where(df_Movies_Budget["Budget"] > 1000000 ,"sí","no")

# %%
#poniendo el unique sabemos que ha funcionado el filtro de mas de 1 millon para large budget.
df_Movies_Budget["Large_Budget"].unique()
df_Movies_Budget
# Out:
#          Budget  Same_Budget Large_Budget
# 0       2070908        36576           sí
# 1       5000000          286           sí
# 2      10000000          259           sí
# 3      20000000          243           sí
# 4       2000000          242           sí
# ...         ...          ...          ...
# 1218  270000000            1           sí
# 1219        923            1           no
# 1220   72500000            1           sí
# 1221    2160000            1           sí
# 1222    1254040            1           sí
#
# [1223 rows x 3 columns]

# %% [markdown]
# **Utilizando la columna de `reservation_status_date`:**
#
# - Cread dos columnas nuevas que correspondan con  el mes y el año.
#
# - Una vez que las hayais creado eliminad la columna `reservation_status_date`
#
# - ¿Qué mes es en el que tenemos más reservas? ¿Y el año?

# %%
def conversion(s):
    try: 
        date = pd.to_datetime(s)
        return date
    except: 
        return None

# %%
from datetime import datetime

df_movies["release_date"] = list(map(conversion,df_movies["release_date"]))
df_movies["año"] = df_movies["release_date"].dt.year
df_movies["mes"] = df_movies["release_date"].dt.month

# %%
df_movies["año"]
df_movies["mes"]
# Out:
# 0        10.0
# 1        12.0
# 2        12.0
# 3        12.0
# 4         2.0
#          ...
# 45461     NaN
# 45462    11.0
# 45463     8.0
# 45464    10.0
# 45465     6.0
# Name: mes, Length: 45466, dtype: float64

# %% [markdown]
# **Ahora no nos interesan los meses en números y queremos tenerlos con letra, es decir, enero, febrero, marzo, etc... Cambiad los valores de la columna "month" para tenerlos en el formato que queremos.**

# %%
Numeros = sorted(list(df_movies["mes"].unique()))
Letras = list(calendar.month_name)[1:]

# %%
dic = dict(zip(Numeros, Letras))
dic
# Out:
# {1.0: 'January',
#  2.0: 'February',
#  3.0: 'March',
#  4.0: 'April',
#  5.0: 'May',
#  6.0: 'June',
#  7.0: 'July',
#  8.0: 'August',
#  9.0: 'September',
#  10.0: 'October',
#  11.0: 'November',
#  12.0: 'December'}

# %%
def formatear_mes(mes, diccionario_conversion = dic):
    try:
        return dic[mes]
    except:
        return None

# %%
df_movies["mes"] = df_movies["mes"].apply(formatear_mes)

# %%
df_movies
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview  ...  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...
# 1      When siblings Judy and Peter discover an encha...  ...
# 2      A family wedding reignites the ancient feud be...  ...
# 3      Cheated on, mistreated and stepped on, the wom...  ...
# 4      Just when George Banks has recovered from his ...  ...
# ...                                                  ...  ...
# 45461        Rising and falling between a man and woman.  ...
# 45462  An artist struggles to finish his work while a...  ...
# 45463  When one of her hits goes wrong, a professiona...  ...
# 45464  In a small town live two brothers, one a minis...  ...
# 45465  50 years after decriminalisation of homosexual...  ...
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45461             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  video  vote_average  vote_count  \
# 0                        Toy Story  False           7.7      5415.0
# 1                          Jumanji  False           6.9      2413.0
# 2                 Grumpier Old Men  False           6.5        92.0
# 3                Waiting to Exhale  False           6.1        34.0
# 4      Father of the Bride Part II  False           5.7       173.0
# ...                            ...    ...           ...         ...
# 45461                       Subdue  False           4.0         1.0
# 45462          Century of Birthing  False           9.0         3.0
# 45463                     Betrayal  False           3.8         6.0
# 45464             Satan Triumphant  False           0.0         0.0
# 45465                     Queerama  False           0.0         0.0
#
#          vote_type     año       mes
# 0      Good Rating  1995.0   October
# 1      Good Rating  1995.0  December
# 2      Good Rating  1995.0  December
# 3      Good Rating  1995.0  December
# 4      Good Rating  1995.0  February
# ...            ...     ...       ...
# 45461   Bad Rating     NaN      None
# 45462  Good Rating  2011.0  November
# 45463   Bad Rating  2003.0    August
# 45464   Bad Rating  1917.0   October
# 45465   Bad Rating  2017.0      June
#
# [45466 rows x 27 columns]

# %% [markdown]
# **¿Cuál es el número medio, el máximo y el mínimo de noches pasadas en fines de semana en funcion del tipo de hotel (columma `hotel`)? ¿Y los días entre semana?**

# %%
df_movies["budget"] = list(map(scanner, df_movies["budget"]))
df_movies["budget"] = list(map(mode_budget,df_movies["budget"]))

presupuesto = df_movies.groupby(["original_title"])["budget"].agg(["mean","max","min"])
presupuesto.head(5)
#Hay muchos valores repetidos porque en mi DataFrame faltaba la información del budget de estas peliculas, y he usado la mediana.
# Out:
#                             mean      max      min
# original_title
# !Women Art Revolution  2070908.0  2070908  2070908
# #1 Cheerleader Camp    2070908.0  2070908  2070908
# #Horror                1500000.0  1500000  1500000
# #Pellichoopulu          200000.0   200000   200000
# #SELFIEPARTY           2070908.0  2070908  2070908

# %% [markdown]
# **¿ Basándonos en el país y en el tipo de hotel, cual es la media de adultos de las reservas?**
#
# **BONUS** Si exploramos los datos del ejercicio anterior, veremos que hay en paises donde solo tenemos un tipo de hotel y en otros tenemos los dos tipos. En este caso, deberéis quedaros solo con aquellos paises que tengan los dos tipos de hoteles. ¿Cuántos países distintos tenemos en este nuevo resultado que acabamos de generar?

# %% [markdown]
# **Basándonos en la columna de `hotel` filtrad los datos para extraer solo los valores de "Resort Hotel"**

# %%
info_movies = df_movies[df_movies["adult"] == "False"]
info_movies.head(5)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...   2070908
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...   2070908
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...
# 1  When siblings Judy and Peter discover an encha...  ...
# 2  A family wedding reignites the ancient feud be...  ...
# 3  Cheated on, mistreated and stepped on, the wom...  ...
# 4  Just when George Banks has recovered from his ...  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video  vote_average  vote_count    vote_type  \
# 0                    Toy Story  False           7.7      5415.0  Good Rating
# 1                      Jumanji  False           6.9      2413.0  Good Rating
# 2             Grumpier Old Men  False           6.5        92.0  Good Rating
# 3            Waiting to Exhale  False           6.1        34.0  Good Rating
# 4  Father of the Bride Part II  False           5.7       173.0  Good Rating
#
#       año       mes
# 0  1995.0   October
# 1  1995.0  December
# 2  1995.0  December
# 3  1995.0  December
# 4  1995.0  February
#
# [5 rows x 27 columns]

# %% [markdown]
# **Basándonos en la columa `meal` extraed solo los valores que correspondan con "BB" y "FB"**

# %%
info_language = df_movies[(df_movies["original_language"] == "en") | (df_movies["original_language"] == "fr")]
info_language
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...   2070908
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...   2070908
# ...      ...                                                ...       ...
# 45459  False                                                NaN   2070908
# 45460  False                                                NaN   2070908
# 45463  False                                                NaN   2070908
# 45464  False                                                NaN   2070908
# 45465  False                                                NaN   2070908
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45459           [{'id': 878, 'name': 'Science Fiction'}]
# 45460  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45459                                   NaN  222848  tt0112613
# 45460                                   NaN   30840  tt0102797
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45459                en              Caged Heat 3000
# 45460                en                   Robin Hood
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview  ...  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...
# 1      When siblings Judy and Peter discover an encha...  ...
# 2      A family wedding reignites the ancient feud be...  ...
# 3      Cheated on, mistreated and stepped on, the wom...  ...
# 4      Just when George Banks has recovered from his ...  ...
# ...                                                  ...  ...
# 45459  It's the year 3000 AD. The world's most danger...  ...
# 45460  Yet another version of the classic epic, with ...  ...
# 45463  When one of her hits goes wrong, a professiona...  ...
# 45464  In a small town live two brothers, one a minis...  ...
# 45465  50 years after decriminalisation of homosexual...  ...
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45459           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45460           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45459                                                NaN
# 45460                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  video  vote_average  vote_count  \
# 0                        Toy Story  False           7.7      5415.0
# 1                          Jumanji  False           6.9      2413.0
# 2                 Grumpier Old Men  False           6.5        92.0
# 3                Waiting to Exhale  False           6.1        34.0
# 4      Father of the Bride Part II  False           5.7       173.0
# ...                            ...    ...           ...         ...
# 45459              Caged Heat 3000  False           3.5         1.0
# 45460                   Robin Hood  False           5.7        26.0
# 45463                     Betrayal  False           3.8         6.0
# 45464             Satan Triumphant  False           0.0         0.0
# 45465                     Queerama  False           0.0         0.0
#
#          vote_type     año       mes
# 0      Good Rating  1995.0   October
# 1      Good Rating  1995.0  December
# 2      Good Rating  1995.0  December
# 3      Good Rating  1995.0  December
# 4      Good Rating  1995.0  February
# ...            ...     ...       ...
# 45459   Bad Rating  1995.0   January
# 45460  Good Rating  1991.0       May
# 45463   Bad Rating  2003.0    August
# 45464   Bad Rating  1917.0   October
# 45465   Bad Rating  2017.0      June
#
# [34707 rows x 27 columns]

# %% [markdown]
# **En este caso, nos interesan los datos donde tengamos reservas sin niños y sin bebes**

# %% [markdown]
# **¿Cuáles son los valores únicos de la columna `children`?**
#
# **¿Por qué nos sale con decimales?**

# %%
#porque tiene Nan y eso hace que todos los valores tengan que ser Float y no puedan ser Int.

# %% [markdown]
# **Reemplazad los valores nulos por la moda**

# %%
#ya he realizado algo similar con el budget.

# %% [markdown]
# **Viendo los valores únicos del número de hijos, hay algo que os llame la antención?**

# %% [markdown]
# **Ahora queremos ordenar nuestros datos, lo haremos por el año** Las condiciones para ordenar son:
#
# - Año: de menor a mayor

# %%
df_movies.sort_values(by = "año", ascending = True, inplace = True)
df_movies
# Out:
#        adult belongs_to_collection   budget  \
# 34940  False                   NaN  2070908
# 34937  False                   NaN  2070908
# 41602  False                   NaN  2070908
# 34933  False                   NaN  2070908
# 34934  False                   NaN  2070908
# ...      ...                   ...      ...
# 45148  False                   NaN  2070908
# 45203  False                   NaN  2070908
# 45338  False                   NaN  2070908
# 45410  False                   NaN  2070908
# 45461  False                   NaN  2070908
#
#                                                   genres  \
# 34940                [{'id': 99, 'name': 'Documentary'}]
# 34937                [{'id': 99, 'name': 'Documentary'}]
# 41602                [{'id': 99, 'name': 'Documentary'}]
# 34933                [{'id': 99, 'name': 'Documentary'}]
# 34934                [{'id': 99, 'name': 'Documentary'}]
# ...                                                  ...
# 45148                                                 []
# 45203  [{'id': 9648, 'name': 'Mystery'}, {'id': 878, ...
# 45338                                                 []
# 45410  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
#
#                                    homepage      id    imdb_id  \
# 34940                                   NaN  315946  tt3155794
# 34937                                   NaN  194079  tt2221420
# 41602                                   NaN  426903  tt5459794
# 34933                                   NaN  159897  tt2075247
# 34934                                   NaN   96882  tt1758563
# ...                                     ...     ...        ...
# 45148                                   NaN  438910  tt0810384
# 45203                                   NaN  433711  tt3158690
# 45338                                   NaN  335251  tt1883368
# 45410                                   NaN  449131  tt0321264
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
#
#       original_language                                  original_title  \
# 34940                xx                                Passage de Venus
# 34937                en                      Sallie Gardner at a Gallop
# 41602                en                                 Buffalo Running
# 34933                xx                     Man Walking Around a Corner
# 34934                xx                                Accordion Player
# ...                 ...                                             ...
# 45148                ru               Konstruktor krasnogo tsveta -1993
# 45203                en  All Superheroes Must Die 2: The Last Superhero
# 45338                en                  The Land Where the Blues Began
# 45410                ru                                           Aprel
# 45461                fa                                         رگ خواب
#
#                                                 overview  ...  \
# 34940  Photo sequence of the rare transit of Venus ov...  ...
# 34937  Sallie Gardner at a Gallop was one of the earl...  ...
# 41602  Individual photographs of the running of a buf...  ...
# 34933  The last remaining production of Le Prince's L...  ...
# 34934  The last remaining film of Le Prince's LPCCP T...  ...
# ...                                                  ...  ...
# 45148  Engineering Red - 1993  Dir: Andrey I. Y. Petr...  ...
# 45203  In a no holds barred documentary, acclaimed jo...  ...
# 45338  An exploration of the musical and social origi...  ...
# 45410                                                NaN  ...
# 45461        Rising and falling between a man and woman.  ...
#
#                                    spoken_languages    status  \
# 34940  [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 34937  [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 41602  [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 34933  [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 34934  [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# ...                                             ...       ...
# 45148                                            []  Released
# 45203      [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45338                                            []  Released
# 45410                                            []  Released
# 45461        [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
#
#                                           tagline  \
# 34940                                         NaN
# 34937                                         NaN
# 41602                                         NaN
# 34933                                         NaN
# 34934                                         NaN
# ...                                           ...
# 45148                                         NaN
# 45203                                         NaN
# 45338                                         NaN
# 45410                                         NaN
# 45461  Rising and falling between a man and woman
#
#                                                 title  video  vote_average  \
# 34940                                Passage of Venus  False           6.0
# 34937                      Sallie Gardner at a Gallop  False           6.2
# 41602                                 Buffalo Running  False           5.4
# 34933                     Man Walking Around a Corner  False           4.1
# 34934                                Accordion Player  False           4.4
# ...                                               ...    ...           ...
# 45148                                 Engineering Red  False           6.0
# 45203  All Superheroes Must Die 2: The Last Superhero  False           4.0
# 45338                  The Land Where the Blues Began  False           0.0
# 45410                                           Aprel  False           6.0
# 45461                                          Subdue  False           4.0
#
#        vote_count    vote_type     año       mes
# 34940        19.0  Good Rating  1874.0  December
# 34937        25.0  Good Rating  1878.0      June
# 41602         7.0  Good Rating  1883.0  November
# 34933        17.0   Bad Rating  1887.0    August
# 34934        18.0   Bad Rating  1888.0   January
# ...           ...          ...     ...       ...
# 45148         2.0  Good Rating     NaN      None
# 45203         1.0   Bad Rating     NaN      None
# 45338         0.0   Bad Rating     NaN      None
# 45410         1.0  Good Rating     NaN      None
# 45461         1.0   Bad Rating     NaN      None
#
# [45466 rows x 27 columns]

# %% [markdown]
# **Ordendad de nuevo el df, pero en este caso en función de número de adultos y niños.** Las condiciones para ordenar son:
#
# - Número de adultos: de mayor a menor
#
# - Número de hijos: de menor a mayor

# %%
df_movies.sort_values(by = "budget", ascending = False, inplace = True)
df_movies
# Out:
#        adult                              belongs_to_collection     budget  \
# 17124  False  {'id': 295, 'name': 'Pirates of the Caribbean ...  380000000
# 11827  False  {'id': 295, 'name': 'Pirates of the Caribbean ...  300000000
# 26558  False  {'id': 86311, 'name': 'The Avengers Collection...  280000000
# 11067  False  {'id': 8537, 'name': 'Superman Collection', 'p...  270000000
# 44842  False  {'id': 8650, 'name': 'Transformers Collection'...  260000000
# ...      ...                                                ...        ...
# 35579  False                                                NaN          1
# 35086  False                                                NaN          1
# 38177  False                                                NaN          1
# 19258  False                                                NaN          1
# 16608  False                                                NaN          1
#
#                                                   genres  \
# 17124  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 11827  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 26558  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11067  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 44842  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# ...                                                  ...
# 35579  [{'id': 9648, 'name': 'Mystery'}, {'id': 10751...
# 35086                      [{'id': 18, 'name': 'Drama'}]
# 38177                     [{'id': 27, 'name': 'Horror'}]
# 19258  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 16608                [{'id': 99, 'name': 'Documentary'}]
#
#                                                 homepage      id    imdb_id  \
# 17124  http://disney.go.com/pirates/index-on-stranger...    1865  tt1298650
# 11827       http://disney.go.com/disneypictures/pirates/     285  tt0449088
# 26558  http://marvel.com/movies/movie/193/avengers_ag...   99861  tt2395427
# 11067                            http://www.superman.com    1452  tt0348150
# 44842                  http://www.transformersmovie.com/  335988  tt3371366
# ...                                                  ...     ...        ...
# 35579                           http://www.salaselts.ee/  339944  tt3949936
# 35086                        http://thelettersmovie.com/  218275  tt1445208
# 38177                                                NaN   35759  tt1488584
# 19258  http://www.ifcfilms.com/films/love-wedding-mar...   59296  tt1436559
# 16608                     http://www.speedandangels.com/   56745  tt1112756
#
#       original_language                               original_title  \
# 17124                en  Pirates of the Caribbean: On Stranger Tides
# 11827                en     Pirates of the Caribbean: At World's End
# 26558                en                      Avengers: Age of Ultron
# 11067                en                             Superman Returns
# 44842                en                Transformers: The Last Knight
# ...                 ...                                          ...
# 35579                et                          Supilinna salaselts
# 35086                en                                  The Letters
# 38177                en                     My Super Psycho Sweet 16
# 19258                en                      Love, Wedding, Marriage
# 16608                en                               Speed & Angels
#
#                                                 overview  ...  \
# 17124  Captain Jack Sparrow crosses paths with a woma...  ...
# 11827  Captain Barbossa, long believed to be dead, ha...  ...
# 26558  When Tony Stark tries to jumpstart a dormant p...  ...
# 11067  Superman returns to discover his 5-year absenc...  ...
# 44842  Autobots and Decepticons are at war, with huma...  ...
# ...                                                  ...  ...
# 35579  "Secret Society of Souptown" is an adventurous...  ...
# 35086  MOTHER TERESA, recipient of the Nobel Peace Pr...  ...
# 38177  A spoiled teens birthday bash turns killer aft...  ...
# 19258  A happy newlywed marriage counselor's views on...  ...
# 16608  Inspired by the passion of two young Navy offi...  ...
#
#                                         spoken_languages    status  \
# 17124  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 11827           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 26558           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 11067  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 44842           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 35579             [{'iso_639_1': 'et', 'name': 'Eesti'}]  Released
# 35086           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 38177           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 19258           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 16608                                                 []  Released
#
#                                               tagline  \
# 17124                     Live Forever Or Die Trying.
# 11827  At the end of the world, the adventure begins.
# 26558                             A New Age Has Come.
# 11067                                             NaN
# 44842      For one world to live, the other must die.
# ...                                               ...
# 35579                                             NaN
# 35086                                             NaN
# 38177                              A party to die for
# 19258                            Here comes the ride.
# 16608           Behind Every Fighter Pilot Is A Dream
#
#                                              title  video  vote_average  \
# 17124  Pirates of the Caribbean: On Stranger Tides  False           6.4
# 11827     Pirates of the Caribbean: At World's End  False           6.9
# 26558                      Avengers: Age of Ultron  False           7.3
# 11067                             Superman Returns  False           5.4
# 44842                Transformers: The Last Knight  False           6.2
# ...                                            ...    ...           ...
# 35579                   Secret Society of Souptown  False           6.8
# 35086                                  The Letters  False           5.6
# 38177                     My Super Psycho Sweet 16  False           6.2
# 19258                      Love, Wedding, Marriage  False           5.1
# 16608                               Speed & Angels  False           3.3
#
#        vote_count    vote_type     año       mes
# 17124      5068.0  Good Rating  2011.0       May
# 11827      4627.0  Good Rating  2007.0       May
# 26558      6908.0  Good Rating  2015.0     April
# 11067      1429.0  Good Rating  2006.0      June
# 44842      1440.0  Good Rating  2017.0      June
# ...           ...          ...     ...       ...
# 35579         8.0  Good Rating  2015.0       May
# 35086        10.0  Good Rating  2015.0  December
# 38177        14.0  Good Rating  2009.0   October
# 19258        73.0  Good Rating  2011.0      June
# 16608         3.0   Bad Rating  2008.0  February
#
# [45466 rows x 27 columns]

# %% [markdown]
# **Después de hacer este último orden, nuestros índices ya no están ordenados, ordenad los índices para que empiecen desde el cero**

# %% [markdown]
# **Momento de practicar con el loc e iloc**
#
# - Extraed todas las columnas para el índice 1
#
# - Extraed las colummas de adultos, niños y bebes de todas las filas pares
#
# - Extraed todas las filas de la columna hotel (utilizad loc o iloc)

# %%
df_movies.iloc[1,:]
# Out:
# adult                                                                False
# belongs_to_collection    {'id': 295, 'name': 'Pirates of the Caribbean ...
# budget                                                           300000000
# genres                   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# homepage                      http://disney.go.com/disneypictures/pirates/
# id                                                                     285
# imdb_id                                                          tt0449088
# original_language                                                       en
# original_title                    Pirates of the Caribbean: At World's End
# overview                 Captain Barbossa, long believed to be dead, ha...
# popularity                                                       31.363664
# poster_path                               /bXb00CkHqx7TPchTGG131sWV59y.jpg
# production_companies     [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# production_countries     [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                           2007-05-19 00:00:00
# revenue                                                        961000000.0
# runtime                                                              169.0
# spoken_languages                  [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                            Released
# tagline                     At the end of the world, the adventure begins.
# title                             Pirates of the Caribbean: At World's End
# video                                                                False
# vote_average                                                           6.9
# vote_count                                                          4627.0
# vote_type                                                      Good Rating
# año                                                                 2007.0
# mes                                                                    May
# Name: 11827, dtype: object

# %%
df_movies.loc[::2, ["budget", "original_language", "original_title"]].head()
# Out:
#           budget original_language  \
# 17124  380000000                en
# 26558  280000000                en
# 44842  260000000                en
# 16130  260000000                en
# 21175  255000000                en
#
#                                     original_title
# 17124  Pirates of the Caribbean: On Stranger Tides
# 26558                      Avengers: Age of Ultron
# 44842                Transformers: The Last Knight
# 16130                                      Tangled
# 21175                              The Lone Ranger
